# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import math
import Analises as an

# %% [markdown]
# # Columns names

# %%
hotel_id = "Hotel ID"
room_id = "Room ID"
tipo_quarto = "Tipo de quarto"
capacidade_max = "Capacidade máxima"
capacidade_min = "Capacidade mínima"
capacidade_max_adultos = "Capacidade máxima de adultos"
capacidade_min_adultos = "Capacidade mínima de adultos"
capacidade_max_criancas = "Capacidade máxima de crianças"
capacidade_min_criancas = "Capacidade mínima de crianças"
capacidade_max_bebes = "Capacidade máxima de bebés"
capacidade_max_camas_extra = "Capacidade máxima de camas extra"
capacidade_max_camas_extra_criancas = "Capacidade máxima de camas extra (crianças)"
capacidade_max_bercos_extra = "Capacidade máxima de berços extra"

# %% [markdown]
# ### Read Data sets

# %%
# hotel = pd.read_csv("../DatasetOriginais/Hotel.csv", delimiter=';')
# facilities = pd.read_csv("../DatasetOriginais/Facilities.csv", delimiter=';')
# tipologias = pd.read_csv("../DatasetOriginais/Quartos_Reservados.csv", delimiter=';')
tipologias = pd.read_csv("../DatasetOriginais/Tipologias.csv", delimiter=';')
# eventos = pd.read_csv("../DatasetOriginais/Eventos.csv", delimiter=';')
# meteorologia = pd.read_csv("../DatasetOriginais/Meteorologia.csv", delimiter=';')
# feriados = pd.read_csv("../DatasetOriginais/Feriados.csv", delimiter=';')
# final = pd.read_csv("../DataSetFinal.csv", delimiter=";")

# %% [markdown]
# ### Análise de quartis

# %%
an.quantileAnalisys(tipologias, 
[
    capacidade_max,
    capacidade_min,
    capacidade_max_adultos,
    capacidade_min_adultos,
    capacidade_max_criancas,
    capacidade_min_criancas,
    capacidade_max_bebes,
    capacidade_max_camas_extra,
    capacidade_max_camas_extra_criancas,
    capacidade_max_bercos_extra
])
# Out:
#       Capacidade máxima  Capacidade mínima  Capacidade máxima de adultos  \
# 0.00                1.0                1.0                           1.0
# 0.25                2.0                1.0                           2.0
# 0.50                3.0                1.0                           2.0
# 0.75                4.0                1.0                           3.0
# 1.00               10.0               10.0                          10.0
#
#       Capacidade mínima de adultos  Capacidade máxima de crianças  \
# 0.00                           1.0                            0.0
# 0.25                           1.0                            0.0
# 0.50                           1.0                            1.0
# 0.75                           1.0                            2.0
# 1.00                          10.0                            8.0
#
#       Capacidade mínima de crianças  Capacidade máxima de bebés  \
# ...

# %% [markdown]
# ### Outliers tipologias: capacidade_max

# %%
an.outliersSimple(tipologias, capacidade_max, tipologias[capacidade_max] <= 10000)
# Out:
# Nº Outliers:  0

# %% [markdown]
# ### Outliers tipologias: capacidade_min

# %%
an.outliersSimple(tipologias, capacidade_min, tipologias[capacidade_min] <= 10000)
# Out:
# Nº Outliers:  0

# %% [markdown]
# ### Outliers tipologias: capacidade_max_adultos

# %%
an.outliersSimple(tipologias, capacidade_max_adultos, tipologias[capacidade_max_adultos] <= 10000)
# Out:
# Nº Outliers:  0

# %% [markdown]
# ### Outliers tipologias: capacidade_min_adultos

# %%
an.outliersSimple(tipologias, capacidade_min_adultos, tipologias[capacidade_min_adultos] <= 10000)
# Out:
# Nº Outliers:  0

# %% [markdown]
# ### Outliers tipologias: capacidade_max_criancas

# %%
an.outliersSimple(tipologias, capacidade_max_criancas, tipologias[capacidade_max_criancas] <= 10000)
# Out:
# Nº Outliers:  0

# %% [markdown]
# ### Outliers tipologias: capacidade_min_criancas

# %%
an.outliersSimple(tipologias, capacidade_min_criancas, tipologias[capacidade_min_criancas] <= 10000)
# Out:
# Nº Outliers:  0

# %% [markdown]
# ### Outliers tipologias: capacidade_max_bebes

# %%
an.outliersSimple(tipologias, capacidade_max_bebes, tipologias[capacidade_max_bebes] <= 10000)
# Out:
# Nº Outliers:  0

# %% [markdown]
# ### Outliers tipologias: capacidade_max_camas_extra

# %%
an.outliersSimple(tipologias, capacidade_max_camas_extra, tipologias[capacidade_max_camas_extra] <= 10000)
# Out:
# Nº Outliers:  0

# %% [markdown]
# ### Outliers tipologias: capacidade_max_camas_extra_criancas

# %%
an.outliersSimple(tipologias, capacidade_max_camas_extra_criancas, tipologias[capacidade_max_camas_extra_criancas] <= 10000)
# Out:
# Nº Outliers:  0

# %% [markdown]
# ### Outliers tipologias: capacidade_max_bercos_extra

# %%
an.outliersSimple(tipologias, capacidade_max_bercos_extra, tipologias[capacidade_max_bercos_extra] <= 10000)
# Out:
# Nº Outliers:  0
