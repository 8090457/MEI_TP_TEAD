# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import math
import Analises as an

# %% [markdown]
# # Columns names

# %%
hotel_id = "hotel_ID"
reservas_id = "Reserve_ID"
num_noites = "num_noites"
ocupacao = "ocupacao"
adultos = "adultos"
criancas = "criancas"
bebes = "bebes"
preco = "preco_euros"
preco_noite = "preco_noite"
preco_noite_adulto = "preco_noite_adulto"
preco_noite_ocupacao = "preco_noite_ocupacao"

# %% [markdown]
# ### Read Data sets

# %%
# hotel = pd.read_csv("../DatasetOriginais/Hotel.csv", delimiter=';')
# facilities = pd.read_csv("../DatasetOriginais/Facilities.csv", delimiter=';')
reservas = pd.read_csv("../DatasetsOutliers/DatasetFinalTest.csv", delimiter=';')
# tipologias = pd.read_csv("../DatasetOriginais/Tipologias.csv", delimiter=';')
# eventos = pd.read_csv("../DatasetOriginais/Eventos.csv", delimiter=';')
# meteorologia = pd.read_csv("../DatasetOriginais/Meteorologia.csv", delimiter=';')
# feriados = pd.read_csv("../DatasetOriginais/Feriados.csv", delimiter=';')
# final = pd.read_csv("../DataSetFinal.csv", delimiter=";")

# %% [markdown]
# ### Análise de quartis

# %%
an.quantileAnalisys(reservas, [num_noites, ocupacao, adultos, criancas, bebes, preco])
# Out:
#       num_noites  ocupacao  adultos  criancas  bebes  preco_euros
# 0.00         1.0       1.0      1.0       0.0    0.0     0.000000
# 0.25         1.0       2.0      2.0       0.0    0.0    75.000000
# 0.50         1.0       2.0      2.0       0.0    0.0   128.000000
# 0.75         2.0       2.0      2.0       0.0    0.0   257.076675
# 1.00        14.0       9.0     30.0       4.0    3.0  8078.000000

# %% [markdown]
# ### Outliers reservas / Num noites

# %%
an.outliersSimple(reservas, num_noites, reservas[num_noites] <= 14)
# Out:
# Nº Outliers:  0

# %% [markdown]
# ### Outliers reservas / Ocupação

# %%
an.outliersSimple(reservas, ocupacao, reservas[ocupacao] <= 5)
# Out:
# Nº Outliers:  71

# %% [markdown]
# ### Adultos

# %%
an.outliersSimple(reservas, adultos, reservas[adultos] <= 15)
# Out:
# Nº Outliers:  5

# %% [markdown]
# ### Crianças

# %%
an.outliersSimple(reservas, criancas, reservas[criancas] <= 4)
# Out:
# Nº Outliers:  0

# %% [markdown]
# ### Bebês

# %%
an.outliersSimple(reservas, bebes, reservas[bebes] <= 10)
# Out:
# Nº Outliers:  0

# %% [markdown]
# ### Preço

# %%
an.outliersSimple(reservas, preco, reservas[preco] <= 5000)
# Out:
# Nº Outliers:  1

# %% [markdown]
# # Preco por noite

# %%
an.outliersSimple(reservas, preco_noite, reservas[preco_noite] <= 2000)
# Out:
# Nº Outliers:  1

# %% [markdown]
# # Preço noite adulto

# %%
an.outliersSimple(reservas, preco_noite_adulto, reservas[preco_noite_adulto] <= 700)
# Out:
# Nº Outliers:  1

# %% [markdown]
# # Preço por noite por ocupantes

# %%
an.outliersSimple(reservas, preco_noite_ocupacao, reservas[preco_noite_ocupacao] < 1000)
# Out:
# Nº Outliers:  1
